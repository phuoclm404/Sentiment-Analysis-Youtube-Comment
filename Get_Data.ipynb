# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pytchat
# Out:
# ...
#      |████████████████████████████████| 69 kB 3.1 MB/s
# ...
#      |████████████████████████████████| 83 kB 1.9 MB/s
# ...
#      |████████████████████████████████| 67 kB 4.6 MB/s
# ...
#      |████████████████████████████████| 57 kB 4.3 MB/s
# ...
#      |████████████████████████████████| 54 kB 2.7 MB/s
# ...
#      |████████████████████████████████| 79 kB 6.1 MB/s
# ...

# %%
# !rm -rf /content/drive/MyDrive/BigData_project/data_real_time

# %%
cd /content/drive/MyDrive/BigData_project
# Out:
# /content/drive/MyDrive/BigData_project

# %%
# !mkdir data_real_time

# %%
cd /content/drive/MyDrive/BigData_project/
# Out:
# /content/drive/MyDrive/BigData_project

# %%
pwd
# Out:
# '/content/drive/MyDrive/BigData_project'

# %%
import pytchat
import time
import json
from datetime import datetime as dt
from uuid import uuid4


livechat = pytchat.create(video_id = "75pz6_GRFhw")# video_id is https://....watch?v=Behind

while livechat.is_alive():
    chatdata = livechat.get()
    for c in chatdata.items:
        print(f"{c.datetime} {c.author.name} {c.message} {c.amountString}")
        name = "./data_real_time/"+ str(dt.now().timestamp())+"_"+str(uuid4())+".json"
        with open(name, 'w', encoding="utf-8") as file:
            file.write(c.json())
    time.sleep(1)
# Out:
# 2022-01-25 16:30:37 Hieu ngo duc ý nghĩa quá. 10 điểm
# 2022-01-25 16:30:37 c0mr4de Tự hào quá
# 2022-01-25 16:30:37 Khanh duy Vlog 10d
# 2022-01-25 16:30:37 nam phạm hay a ơi 10đ
# 2022-01-25 16:30:37 Quân Võ ây do
# 2022-01-25 16:30:37 Mạnh Cường :red_heart:
# 2022-01-25 16:30:37 NDQ 100đ
# 2022-01-25 16:30:37 Nhu Dang anh cống hiến thế
# 2022-01-25 16:30:37 Hưng Trần Quang 10 điểm
# 2022-01-25 16:30:37 ミKing•Akameミ 10 điểm
# 2022-01-25 16:30:37 Cao Lan Nhi 10đ
# 2022-01-25 16:30:37 Bảo Thanh La Huỳnh :virtualhug:
# 2022-01-25 16:30:38 Lê Thành Long Đỉnh
# 2022-01-25 16:30:37 AudreyD đỉnh
# 2022-01-25 16:30:38 BinBlack gaming 10đ
# 2022-01-25 16:30:38 Viet Pham quoc :red_heart::red_heart::red_heart::red_heart::red_heart:
# 2022-01-25 16:30:38 Việt Hồ Eo ôi thương thế
# 2022-01-25 16:30:38 Sony 10₫
# 2022-01-25 16:30:38 Tuyển Khương Đình Cảm ơn anh
# 2022-01-25 16:30:38 Nguyễn Văn Thông :red_heart::red_heart::red_heart::red_heart::red_heart:
# ...
